# %% [markdown]
# # PoC : News RAG LLM

# %% [markdown]
# 1. Load required libraries
# 2. load "News_Category_Dataset_v3
# 3. Preprocess the dataset

# %%
#Load required Libraries

import json
import pandas as pd 
import numpy as np
from bs4 import BeautifulSoup
import requests
import time
import re
from concurrent.futures import ThreadPoolExecutor
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# %%
data =[]
with open('News_Category_Dataset_v3.json','r', encoding='utf-8') as file:
    for line in file:
        if line.strip(): #empty lines result in false condition
            data.append(json.loads(line)) #parse json file and append to list

print(f"There are {len(data)} articles in the dataset.")

#preview
print(data[:5])
# Out:
# There are 209527 articles in the dataset.
# [{'link': 'https://www.huffpost.com/entry/covid-boosters-uptake-us_n_632d719ee4b087fae6feaac9', 'headline': 'Over 4 Million Americans Roll Up Sleeves For Omicron-Targeted COVID Boosters', 'category': 'U.S. NEWS', 'short_description': 'Health experts said it is too early to predict whether demand would match up with the 171 million doses of the new boosters the U.S. ordered for the fall.', 'authors': 'Carla K. Johnson, AP', 'date': '2022-09-23'}, {'link': 'https://www.huffpost.com/entry/american-airlines-passenger-banned-flight-attendant-punch-justice-department_n_632e25d3e4b0e247890329fe', 'headline': 'American Airlines Flyer Charged, Banned For Life After Punching Flight Attendant On Video', 'category': 'U.S. NEWS', 'short_description': "He was subdued by passengers and crew when he fled to the back of the aircraft after the confrontation, according to the U.S. attorney's office in Los Angeles.", 'authors': 'Mary Papenfuss', 'date': '2022-09-23'}, {'link': 'https://www.huffpost.com/entry/funniest-tweets-cats-dogs-september-17-23_n_632de332e4b0695c1d81dc02', 'headline': '23 Of The Funniest Tweets About Cats And Dogs This Week (Sept. 17-23)', 'category': 'COMEDY', 'short_description': '"Until you have a dog you don\'t understand what could be eaten."', 'authors': 'Elyse Wanshel', 'date': '2022-09-23'}, {'link': 'https://www.huffpost.com/entry/funniest-parenting-tweets_l_632d7d15e4b0d12b5403e479', 'headline': 'The Funniest Tweets From Parents This Week (Sept. 17-23)', 'category': 'PARENTING', 'short_description': '"Accidentally put grown-up toothpaste on my toddler’s toothbrush and he screamed like I was cleaning his teeth with a Carolina Reaper dipped in Tabasco sauce."', 'authors': 'Caroline Bologna', 'date': '2022-09-23'}, {'link': 'https://www.huffpost.com/entry/amy-cooper-loses-discrimination-lawsuit-franklin-templeton_n_632c6463e4b09d8701bd227e', 'headline': 'Woman Who Called Cops On Black Bird-Watcher Loses Lawsuit Against Ex-Employer', 'category': 'U.S. NEWS', 'short_description': 'Amy Cooper accused investment firm Franklin Templeton of unfairly firing her and branding her a racist after video of the Central Park encounter went viral.', 'authors': 'Nina Golgowski', 'date': '2022-09-22'}]

# %%
#create df
news_data= pd.DataFrame.from_dict(data, orient = 'columns')
df= news_data.sample(frac=0.1, random_state=42)  #make copy for preprocessing tasks

print(f"The dataset has {df.shape[1]} features and {df.shape[0]} rows.\nThe names of the categories are: {df.columns.tolist()}")

#preview dataframe
df.head()
# Out:
# The dataset has 6 features and 20953 rows.
# The names of the categories are: ['link', 'headline', 'category', 'short_description', 'authors', 'date']
#                                                      link  \
# 128310  https://www.huffingtonpost.com/entry/what-if-w...
# 139983  https://www.huffingtonpost.comhttp://www.washi...
# 42339   https://www.huffingtonpost.com/entry/time-runs...
# 131494  https://www.huffingtonpost.com/entry/one-glimp...
# 163649  https://www.huffingtonpost.com/entry/mens-swea...
#
#                                                  headline  category  \
# 128310    What If We Were All Family Generation Changers?    IMPACT
# 139983        Firestorm At AOL Over Employee Benefit Cuts  BUSINESS
# 42339   Dakota Access Protesters Arrested As Deadline ...  POLITICS
# 131494  One Glimpse Of These Baby Kit Foxes And You'll...     GREEN
# 163649  Mens' Sweat Pheromone, Androstadienone, Influe...   SCIENCE
#
#                                         short_description  \
# 128310  What if, in doing so, we won't just create new...
# 139983  It should have been a glorious week for AOL ch...
# 42339   A few protesters who refused to leave remained...
# 131494
# 163649  Scientists didn't know if humans played that g...
#
#                                                   authors        date
# 128310  Matt Murrie, ContributorEdupreneur, Cofounder/...  2014-06-20
# 139983                                                     2014-02-08
# 42339   Michael McLaughlin & Josh Morgan, The Huffingt...  2017-02-22
# 131494                                                     2014-05-14
# 163649                                     Melissa Cronin  2013-06-02

# %%
#check for missing values
df.isna().sum()
# Out:
# link                 0
# headline             0
# category             0
# short_description    0
# authors              0
# date                 0
# dtype: int64

# %%
def duplicated_manager(dataframe):

    try:
        if dataframe.duplicated().sum() != 0:
            dataframe.drop_duplicates(keep ='first',ignore_index=True, inplace=True )

            #Validate duplicated values removed
            print(f" Duplicates successfully managed. There are now {dataframe.duplicated().sum()} duplicates.")
        else:
            print('There are no duplicates in the data')
        return dataframe
    except Exception as e:
        print(f" Error encountered removing duplicates: {e} ")

# %%
#check for duplicates

print(f" There are {df.duplicated().sum()} duplicated articles")

df[df.duplicated(keep=False )][:4]
# Out:
#  There are 0 duplicated articles
# Empty DataFrame
# Columns: [link, headline, category, short_description, authors, date]
# Index: []

# %%
#Handle duplicates
df =duplicated_manager(df)
# Out:
# There are no duplicates in the data

# %% [markdown]
# ### Extract full artcile from links

# %%
#test regular expression for identifying more than one url in each row
#url = 'https://www.huffingtonpost.comhttp://www.motherjones.com/politics/2016/05/trump-butler-anthony-senecal-facebook-kill-obama'

#url_pattern = r'(https?://[^\s"<>]*?)(?=(?:https?://|$))'
#found_urls = re.findall(url_pattern, url)
#found_urls

# %%
#Check how many rows have more than one link concatenated together 
#urls = df['link'].loc[:].tolist()
#url_pattern = r'(https?://[^\s"<>]*?)(?=(?:https?://|$))'
#i=0
#if urls:
    #for url in urls:
        #if len(re.findall(url_pattern, url)) >1:
            #i+=1
#i

# %%
def count_url(url):

    url_pattern = r'(https?://[^\s"<>]*?)(?=(?:https?://|$))'

    if isinstance(url, str):
        return 1 if len(re.findall(url_pattern, url)) >1 else 0
    
    elif isinstance(url,pd.Series):

        count=0
        for val in url:
            if len(re.findall(url_pattern, val)) >1:
                 count+=1
        return f"The dataframe has {count} rows with concatenated URLs."
        
    else:
        raise TypeError("Input must be a string or pandas Series")

# %%
def extract_url(url):

    if not isinstance(url, str):
        raise TypeError("Column name must be a string")
    
    url_pattern = r'(https?://[^\s"<>]*?)(?=(?:https?://|$))'
    try:
        matches= re.findall(url_pattern, url) #separte the urls

        if matches:
            article_url =matches[-1] #taking last url as valid article url 
        return article_url

    except Exception as e:
        print(f"Error removing url: {str(e)}")

# %%
df['article_url'] = df['link'].apply(extract_url)

# %%
# Check for remaining malformed URLs
bad_urls = df[df['article_url'].str.contains('http://http|https://https')]
print(f"Found {len(bad_urls)} still-malformed URLs")
# Out:
# Found 0 still-malformed URLs

# %%
count_url(df['article_url'])
# Out:
# 'The dataframe has 0 rows with concatenated URLs.'

# %%
def get_article(url):
    if not isinstance(url, str):
        raise TypeError('URL must be a string format')
    
    contents = None
    paragraphs = []  # Initialize paragraphs to avoid reference errors
    
    try:
        # Configure session with redirect limits
        session = requests.Session()

        # Set max_redirects to 5 (default is 30)
        adapter = HTTPAdapter(
            max_retries=Retry(total=3, backoff_factor=1),
            pool_connections=10,         # Connection pool size
            pool_maxsize=10,
        )
        adapter.max_redirects = 5

        session.mount("http://", adapter)
        session.mount("https://", adapter)
        
        print(f"Processing URL: {url}...")  # Show  URL

        headers = {'User-Agent': 'Mozilla/5.0'}
        url_call = session.get(url,
                                headers=headers, 
                                timeout=10,                                
                                )
        
        if url_call.status_code == 200:
            soup = BeautifulSoup(url_call.content, 'html.parser')
            print(" ->Parsing HTML content...")

            # Try multiple selectors - expanded list
            selectors = [
                ('article', 'entry-content'),
                ('article', 'entry__content'),
                ('div', 'article-body'),
                ('div', 'article-content'),
                ('div', 'post-content'),
                ('div', 'hz-editorial')

            ]
            
            for tag, class_name in selectors:
                url_text = soup.find(tag, class_=class_name)
                
                if url_text:
                    print(f" -> Found article with {tag}.{class_name}")
                    paragraphs = [p.get_text(strip=True) for p in url_text.find_all('p')]
                    contents = ' '.join(paragraphs)
                    print(f" ->Extracted {len(paragraphs)} paragraphs ({len(contents)} chars)")
                    return contents
                    
            
            print(" -> No article content found with standard selectors")

    except requests.exceptions.TooManyRedirects:
        print(f" -> Skipping (too many redirects): {url[:60]}...")
    except requests.exceptions.SSLError:
        print(f" -> Skipping (SSL error): {url[:60]}...") 
    except requests.exceptions.ConnectionError:
        print(f" -> Skipping (connection failed): {url[:60]}...")
    except requests.exceptions.Timeout:
        print(f" -> Skipping (timeout): {url[:60]}...")
    except Exception as e:
        print(f" -> Skipping (error: {str(e)[:50]}...): {url[:60]}...")
    
    return None


# Process URLs in batches (adjust max_workers based on your system)

def parallel_scrape(urls):
    with ThreadPoolExecutor() as executor:
        return list(executor.map(get_article, urls))
    

def is_scrapable(url):
    if not isinstance(url, str):
        return False
        
    skip_domains = {
        'houzz.com',
        'theatlanticcities.com', 
        'dailycandy.com'
    }
    domain = url.split('//')[-1].split('/')[0].lower()
    return not any(skip in domain for skip in skip_domains)

# Apply filter before processing
#df['scrapable'] = df['article_url'].apply(is_scrapable)
#scrapable_df = df[df['scrapable']].copy()

# %%
#urls= df['article_url'].tolist()

# %%
# Initialize article column if needed
if 'article' not in df.columns:
    df['article'] = None

batch_size = 2500
scrapable_idx = df[df['scrapable']].index
total_batches = (len(scrapable_idx)) // batch_size + 1

for batch_num, i in enumerate(range(0, len(scrapable_idx), batch_size)):
    batch_end = min(i + batch_size, len(scrapable_idx))
    batch_indices = scrapable_idx[i:batch_end]
    
    # Clear progress message
    print(f"\nProcessing batch {batch_num + 1}/{total_batches} (rows {i}-{batch_end-1})", end="\r")
    
    # Process batch
    batch_urls = df.loc[batch_indices, 'article_url'].tolist()
    results = parallel_scrape(batch_urls)
    
    # Update DataFrame
    df.loc[batch_indices, 'article'] = results
    
    # Save progress
    df.to_csv("progress_checkpoint.csv", index=False)
    print(f"✅ Batch {batch_num + 1}/{total_batches} complete - {sum(x is not None for x in results)}/{len(results)} successful")
# Out:
# Processing URL: https://www.huffingtonpost.com/entry/what-if-we-were-all-famil_b_5510958.html...
# Processing URL: http://www.washingtonpost.com/business/economy/aol-chief-ignites-firestorm-over-401k-cuts-and-distressed-babies-remark/2014/02/07/2116c03a-9012-11e3-b227-12a45d109e03_story.html...
# Processing URL: https://www.huffingtonpost.com/entry/time-runs-out-at-main-dakota-access-pipeline-protest-camp_us_58acc6a9e4b04a0b274df548...
# Processing URL: https://www.huffingtonpost.com/entry/one-glimpse-of-these-baby_n_5319015.html...
# Processing URL: https://www.huffingtonpost.com/entry/mens-sweat-pheromone-cooperation_us_5baeb6f0e4b014374e2e5ae6...
# Processing URL: https://www.huffingtonpost.com/entry/sleepover_us_5b9c0b18e4b03a1dcc7bf30b...
# Processing URL: https://www.huffingtonpost.com/entry/making-goals_us_5b9c788ee4b03a1dcc7ef3c9...
# Processing URL: https://www.huffingtonpost.com/entry/maybe-colleges-should-take-a-lesson-from-zoos_us_591325eee4b0e070cad70a9b...
# Processing URL: https://www.huffingtonpost.com/entry/stephanie-seymour-photo-sons_us_5b9ddb44e4b03a1dcc8dc9ec...
# Processing URL: https://www.huffingtonpost.com/entry/american-attitudes-about-guns-have-become-much-more-positive-but-why_us_597a1afae4b02a8434b4cb25...
# Processing URL: https://www.huffingtonpost.com/entry/carl-bernstein-clinton-emails_us_5814eeace4b0990edc31a2be...
# Processing URL: https://www.huffingtonpost.com/entry/nc-school-official-wants-kids-to-carry-pepper-spray-in-trans-friendly-bathrooms_us_573259a1e4b016f378977bc0...
# Processing URL: https://www.huffingtonpost.com/entry/6-tips-that-could-help-yo_b_7725742.html...
# Processing URL: https://www.huffingtonpost.com/entry/north-koreas-slur-of-pres_b_6386960.html...
# Processing URL: https://www.huffingtonpost.com/entry/rachel-ryle-instagramming-the-world_n_5836508.html...
# Processing URL: https://www.huffingtonpost.com/entry/why-women-stay-in-bad-mar_us_5b9d9799e4b03a1dcc89e7ed...
# Processing URL: https://www.huffingtonpost.com/entry/grance-gay-marriage_us_5bafb43de4b0ad769260647b...
# Processing URL: https://www.huffingtonpost.com/entry/happiness-depression_b_6609116.html...
# Processing URL: https://www.huffpost.com/entry/bc-us-biden-putin-call_n_61cc9fcce4b04b42ab70dffd...
# Processing URL: https://www.huffingtonpost.com/entry/anna-dello-russo-hm-hat-video_us_5b9c6b7de4b03a1dcc7e8152...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (1628 chars)
# Processing URL: https://www.huffingtonpost.com/entry/egg-cooking-gadgets_us_57ed2c11e4b024a52d2d3139...
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
# Processing URL: http://thehill.com/blogs/on-the-money/banking-financial-institutions/284461-wall-street-watchdogs-will-feel-sequesters-bite-...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 15 paragraphs (2543 chars)
# Processing URL: https://www.huffingtonpost.com/entry/hong-kong-escalator-reversing_us_58d90d28e4b03692bea7ab96...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 3 paragraphs (387 chars)
# Processing URL: http://abcnews.go.com/Politics/wireStory/trump-potential-gop-convention-battle-38796105...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 15 paragraphs (3635 chars)
# Processing URL: https://www.huffingtonpost.com/entry/blended-family-friday_us_5b9d2005e4b03a1dcc84accd...
# Processing URL: http://www.zocalopublicsquare.org/2016/04/28/meet-the-new-president-of-l-a-s-berggruen-institute/personalities/in-the-green-room/...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 29 paragraphs (6878 chars)
# Processing URL: https://www.huffingtonpost.com/entry/kardashian-kurves-contest-plus-size_us_5b9c0d85e4b03a1dcc7c06fe...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 8 paragraphs (3927 chars)
# Processing URL: https://www.huffingtonpost.com/entry/bill-hader-hosting-snl-saturday-night-live_n_5836756.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 19 paragraphs (4043 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 17 paragraphs (6922 chars)
# Processing URL: https://www.huffingtonpost.com/entry/opioid-addiction-patient-limits-suboxone_us_56f9aa0be4b0143a9b491020...
# Processing URL: https://www.huffingtonpost.com/entry/left-turns-talking-distracting-distracted-driving_us_5b9cde08e4b03a1dcc82904f...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 41 paragraphs (8028 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 4 paragraphs (2862 chars)
# Processing URL: https://www.huffingtonpost.com/entry/celeb-halloween-costumes_us_5b9d9406e4b03a1dcc89bf0c...
# Processing URL: https://www.huffingtonpost.com/entry/charlie-hebdo-rally_n_6451286.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 16 paragraphs (4138 chars)
# Processing URL: https://www.huffingtonpost.com/entry/as-long-as-there-is-american-sitcom_b_7092566.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 6 paragraphs (1256 chars)
# Processing URL: https://www.huffingtonpost.com/entry/syria-toxic-gas-attack_us_57a06263e4b0e2e15eb70bd7...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 21 paragraphs (6062 chars)
# Processing URL: https://www.huffingtonpost.com/entry/how-raising-an-introvert-made-me-a-better-educator_us_56d8760ce4b0000de4039b9d...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 26 paragraphs (3881 chars)
# Processing URL: https://www.huffingtonpost.com/entry/prince-george-doll_us_5b9db76be4b03a1dcc8bec08...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 28 paragraphs (6606 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (1666 chars)
# Processing URL: https://www.huffingtonpost.com/entry/pfizer-allergan-scrap-160-billion-merger_us_5704edede4b0537661882620...
# Processing URL: https://www.huffingtonpost.com/entry/activist-urges-for-more-awareness-after-suicide-convention_us_562643c0e4b02f6a900dc903...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 27 paragraphs (4603 chars)
# Processing URL: https://www.huffingtonpost.com/entry/ebola-new-york-city_n_6041536.html...
# Processing URL: https://www.huffingtonpost.com/entry/14-rose-gold-beauty-products-thatll-make-you-look-like-24-karats_us_579f918ce4b08a8e8b5ed8df...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 6 paragraphs (1181 chars)
# Processing URL: https://www.huffingtonpost.com/entry/ohio-innocence-project_us_57d6cd59e4b03d2d459b7619...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 18 paragraphs (3804 chars)
# Processing URL: https://www.huffingtonpost.com/entry/bbq-sauce-recipes_us_5b9d977ee4b03a1dcc89e4de...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 18 paragraphs (2780 chars)
# Processing URL: https://www.huffingtonpost.com/entry/top-5-tastes-stone-fruit_us_5b9d6ee5e4b03a1dcc87efd8...
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
# Processing URL: https://www.huffpost.com/entry/james-clapper-trump-bin-laden_n_5bf3f065e4b01909c80938d5...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 6 paragraphs (1006 chars)
# Processing URL: https://www.huffingtonpost.com/entry/trump-fbi-director-comey_us_5913321ee4b0a58297e16ec3...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 36 paragraphs (10439 chars)
# Processing URL: https://www.huffingtonpost.com/entry/mark-hamill-last-jedi-luke-skywalker_us_5a3cf644e4b025f99e16864d...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (2491 chars)
# Processing URL: https://www.huffingtonpost.com/entry/meningitis-outbreak-nowhere-near-end-wiliam-schaffner_us_5b9c69e6e4b03a1dcc7e74af...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 21 paragraphs (5794 chars)
# Processing URL: https://www.huffingtonpost.com/entry/is-your-outdated-career-m_b_7245648.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 11 paragraphs (1747 chars)
# Processing URL: https://www.huffingtonpost.com/entry/holiday-gift-bags-wrapping-paper_us_5b9c92c9e4b03a1dcc7ff2a9...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 11 paragraphs (2474 chars)
# Processing URL: http://www.theshadowleague.com/articles/pour-out-a-lil-liquor-for-the-nfl-s-diva-receiver-era...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 18 paragraphs (5617 chars)
# Processing URL: https://www.huffingtonpost.com/entry/11-year-old-running-half-marathon-to-save-the-wolves_b_7110252.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 23 paragraphs (3051 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 31 paragraphs (8507 chars)
# Processing URL: https://www.huffingtonpost.com/entry/the-tipsy-hostess-guide-to-moving_us_5b9d2c7de4b03a1dcc852a57...
# Processing URL: https://www.huffingtonpost.com/entry/taxes-nightmare-for-homes_us_5b9d55aee4b03a1dcc86c55d...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 24 paragraphs (5641 chars)
# Processing URL: https://www.huffingtonpost.com/entry/marco-rubio-social-security_us_56e230abe4b065e2e3d5781d...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (6049 chars)
# Processing URL: https://www.huffingtonpost.com/entry/fearless-girl-meet-righteous-brother_us_58f4a826e4b048372700d9c5...
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
# Processing URL: https://www.huffingtonpost.com/entry/intimacy-after-loss_us_5b9d9e96e4b03a1dcc8a5502...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 12 paragraphs (1974 chars)
# Processing URL: https://www.huffingtonpost.com/entry/people-with-this-eye-color-are-at-higher-risk-of-alcoholism_us_55a3daa6e4b0b8145f730811...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 5 paragraphs (683 chars)
# Processing URL: https://www.huffingtonpost.com/entry/trolltunga_us_5b9da879e4b03a1dcc8af447...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 12 paragraphs (1515 chars)
# Processing URL: https://www.huffingtonpost.com/entry/nonagenarians-go-on-blind-date-at-bookstore-ditch-the-dating-apps_us_5717ccb4e4b0479c59d6c328...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 16 paragraphs (2630 chars)
# Processing URL: https://www.huffingtonpost.com/entry/parkour-gym-soft-indoor_us_5b9d9393e4b03a1dcc89ba2d...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 15 paragraphs (3255 chars)
# Processing URL: https://www.huffingtonpost.com/entry/technology-meditation_us_5b9cb4aee4b03a1dcc810f95...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 17 paragraphs (3741 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 18 paragraphs (2750 chars)
# Processing URL: https://www.huffingtonpost.com/entry/kesha-dr-luke-lawsuit_us_5705a132e4b053766188b636...
# Processing URL: https://www.huffingtonpost.com/entry/new-jersey-mountain-home_us_5b9d6205e4b03a1dcc874fe9...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 28 paragraphs (5126 chars)
# Processing URL: https://www.huffingtonpost.com/entry/joseph-gordon-levitt-don-jons-addiction_us_5bb41302e4b066f8d2545166...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 11 paragraphs (1565 chars)
# Processing URL: https://www.huffingtonpost.com/entry/fashion-week-live-blog_us_5b9dd35ee4b03a1dcc8d62d8...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 29 paragraphs (5552 chars)
# Processing URL: https://www.huffingtonpost.com/entry/bob-woodward-hillary-clinton_us_56b21b55e4b08069c7a59b98...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (7689 chars)
# Processing URL: https://www.huffingtonpost.com/entry/hotel-suites-good-enough_us_5b9c4fb6e4b03a1dcc7db8b9...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (3105 chars)
# Processing URL: https://www.huffingtonpost.com/entry/john-corbett-actor-sex-and-the-city_us_5b9d26ade4b03a1dcc84ecd6...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 19 paragraphs (4185 chars)
# Processing URL: https://www.huffingtonpost.com/entry/19-kids-and-counting_us_5b9d9402e4b03a1dcc89be9e...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (1870 chars)
# Processing URL: https://www.huffingtonpost.com/entry/polls-clinton-leading-tight-race_us_57d69c87e4b00642712e3896...
# Processing URL: https://www.huffingtonpost.com/entry/packers-block-punt-ravens-first-down-gif_us_5bb715cde4b097869fd42135...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 25 paragraphs (9401 chars)
# Processing URL: https://www.huffingtonpost.com/entry/friday-talking-points-liar-liar_us_593b465be4b094fa859f1875...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 15 paragraphs (3625 chars)
# Processing URL: https://www.huffingtonpost.com/entry/rms-st-helena-last-of-the_b_6281038.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 10 paragraphs (2146 chars)
# Processing URL: https://www.huffingtonpost.com/entry/10-worst-provisions-in-the-republican-appropriations_us_59ba9215e4b0390a1564db62...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 36 paragraphs (5863 chars)
# Processing URL: https://www.huffingtonpost.com/entry/the-best-hotel-coffee-bars_us_5b9c6ee0e4b03a1dcc7e97b2...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 19 paragraphs (3623 chars)
# Processing URL: https://www.huffingtonpost.com/entry/the-battle-of-identities_b_5171526.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 15 paragraphs (2608 chars)
# Processing URL: https://www.huffingtonpost.com/entry/chipotle-paid-sick-leave_us_56a11964e4b076aadcc582fa...
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
# Processing URL: https://www.huffingtonpost.com/entry/dylan-autism-and-the-butterfly-effect_b_7000056.html...
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
# Processing URL: https://www.huffingtonpost.com/entry/most-interesting-hotel-amenities_us_5b9cd6cbe4b03a1dcc824c27...
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
# Processing URL: https://www.huffingtonpost.com/entry/you-dont-need-rosecolored_b_7701686.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (2124 chars)
# Processing URL: https://www.huffingtonpost.com/entry/uber-waymo-settlement_us_5a7dc809e4b044b3821ccbc7...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 19 paragraphs (3506 chars)
# Processing URL: https://www.huffingtonpost.com/entry/scott-pruitt-security-epa_us_5afaaee1e4b0200bcab89d80...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 29 paragraphs (10525 chars)
# Processing URL: https://www.huffingtonpost.com/entry/romantic-honeymoon-hotels_us_5b9cf542e4b03a1dcc834709...
# Processing URL: https://www.huffingtonpost.com/entry/an-honest-customs-declaration-form_us_5b9bdecde4b03a1dcc7adcae...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 29 paragraphs (4944 chars)
# Processing URL: https://www.huffingtonpost.com/entry/easter-cheese-crescia_b_5170747.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 4 paragraphs (543 chars)
# Processing URL: https://www.huffingtonpost.com/entry/5-boutique-hotels-sexy_us_5b9cdcb9e4b03a1dcc82833c...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 12 paragraphs (951 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 7 paragraphs (1117 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (1381 chars)
# Processing URL: https://www.huffingtonpost.com/entry/one-formula-to-lead-and-l_b_5844908.html...
# Processing URL: https://www.huffpost.com/entry/chris-hayes-donald-trump-resign-coronavirus-pandemic_n_5ef6e9c7c5b6acab2841f81f...
# Processing URL: https://www.huffingtonpost.com/entry/naked-man-crashes-car-sex-la-grande-washington_us_5a19574fe4b0d4906caf01b1...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 26 paragraphs (7544 chars)
# Processing URL: https://www.huffingtonpost.com/entry/breast-cancer-vaccine_us_5b9d10f5e4b03a1dcc843bd6...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 12 paragraphs (1406 chars)
# Processing URL: https://www.huffingtonpost.com/entry/patricia-smith-embezzlement-acura_us_5b9be152e4b03a1dcc7aeeb4...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 68 paragraphs (18806 chars)
# Processing URL: https://www.huffingtonpost.com/entry/dustin-lance-black-surrogacy-response_us_5ac242b1e4b0f112dc9de8f9...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 14 paragraphs (3085 chars)
# Processing URL: https://www.huffingtonpost.com/entry/noah-syndergaard-trump-hurricanes_us_59c0e998e4b087fdf507ba5c...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 27 paragraphs (7488 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 31 paragraphs (11925 chars)
# Processing URL: https://www.huffingtonpost.com/entry/cadbury-eggs-vs-peeps_us_5b9b89cae4b03a1dcc7870fa...
# Processing URL: https://www.huffingtonpost.com/entry/floyd-mayweather-girlfriend-miss-shantel-jackson-video_us_5bb6a0fae4b097869fd2043e...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 5 paragraphs (490 chars)
# Processing URL: http://www.fodors.com/news/holiday-foods-around-the-world-6267.html?ref=twt_fd_huffpo6267...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 8 paragraphs (1669 chars)
# Processing URL: https://www.huffingtonpost.com/entry/saudi-high-risk-bet-in-ye_b_5895984.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 5 paragraphs (948 chars)
# Processing URL: https://www.huffingtonpost.com/entry/say-yes-to-the-dress-watching-tv_us_5b9c0460e4b03a1dcc7bc9fb...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 8 paragraphs (2098 chars)
# Processing URL: https://www.huffingtonpost.com/entry/cheese-marry_us_5b9d96bee4b03a1dcc89d90d...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 4 paragraphs (794 chars)
# Processing URL: https://www.huffingtonpost.com/entry/paula-deen-weight-loss-family_us_5b9cbfd0e4b03a1dcc8177c1...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 29 paragraphs (3306 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 29 paragraphs (5592 chars)
# Processing URL: https://www.huffingtonpost.com/entry/pharmaceutical-companies-are-price-gouging-vaccines-for-refugees-aid-group_us_57a3950ee4b03ba68011b5a1...
# Processing URL: https://www.huffingtonpost.com/entry/milk-in-my-sippy-cup-kid-rap_us_5b9bdee6e4b03a1dcc7add3c...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 3 paragraphs (818 chars)
# Processing URL: https://www.huffingtonpost.com/entry/darren-wilson-video-radio_n_6161930.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 6 paragraphs (933 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 31 paragraphs (5855 chars)
# Processing URL: https://www.huffingtonpost.com/entry/brian-maixner-kansas-diner_n_6833460.html...
# Processing URL: https://www.huffingtonpost.com/entry/david-clarke-facebook-taunts-trial_us_5a515d3be4b003133ec85026...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (1362 chars)
# Processing URL: https://www.huffingtonpost.com/entry/donald-trump-jeb-bush-2016_n_7775390.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 8 paragraphs (2022 chars)
# Processing URL: https://www.huffingtonpost.com/entry/getting-the-bird-from-a-bird_b_6794938.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 4 paragraphs (603 chars)
# Processing URL: https://www.huffingtonpost.com/entry/bill-vet-bars-wellness-centers_us_5640fd44e4b0307f2cae7610...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 8 paragraphs (2368 chars)
# Processing URL: https://www.huffingtonpost.com/entry/huffpost-rise-morning-newsbrief-june-9_us_575913a1e4b00f97fba74bfc...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 11 paragraphs (4583 chars)
# Processing URL: https://www.huffpost.com/entry/trump-legacy-impeachment-insurrection-lies-corruption_n_6001ff22c5b6efae62f88bd4...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (1260 chars)
# Processing URL: https://www.huffingtonpost.com/entry/toys-r-us-jingle-minor-key_us_5aab60b0e4b0337adf82a87b...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 19 paragraphs (3446 chars)
# Processing URL: https://www.huffingtonpost.com/entry/the-past-neat-or-on-the-r_b_6397172.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 30 paragraphs (8515 chars)
# Processing URL: https://www.huffingtonpost.com/entry/federal-requests-for-patient-info-raise-red-flags-in-states-that-allow-medical-pot-use_us_59b85c78e4b0edff97175dea...
# Processing URL: https://www.huffingtonpost.com/entry/prep-school-owen-labrie-prison_us_56edaac2e4b084c672207223...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 6 paragraphs (1250 chars)
# Processing URL: https://www.huffingtonpost.com/entry/pakistan-peshawar-bombings-christians_us_57cacea5e4b0a22de0963177...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 15 paragraphs (2861 chars)
# Processing URL: https://www.huffingtonpost.com/entry/max-is-a-weeper-and-a-kee_b_7679676.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (2380 chars)
# Processing URL: https://www.huffingtonpost.com/entry/privacy_us_5b9df5c8e4b03a1dcc8f8eb2...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 33 paragraphs (11127 chars)
# Processing URL: https://www.huffingtonpost.com/entry/katie-holmes-divorce-suri_us_5b9c0c42e4b03a1dcc7bfe9b...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 3 paragraphs (671 chars)
# Processing URL: https://www.huffingtonpost.com/entry/alzheimers-disease_us_5b9c894ee4b03a1dcc7f8fc2...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 23 paragraphs (4388 chars)
# Processing URL: https://www.huffingtonpost.com/entry/check-cashiers-paperless-future_us_5b9c314fe4b03a1dcc7cfb2c...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 2 paragraphs (315 chars)
# Processing URL: https://www.huffingtonpost.com/entry/spider-man-pick-up-basketball_us_5bad27d4e4b04234e8575a78...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 17 paragraphs (3927 chars)
# Processing URL: https://www.huffingtonpost.com/entry/saudi-arabia-black-panther-screening_us_5ad8e314e4b03c426dac7b99...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 18 paragraphs (4787 chars)
# Processing URL: https://www.huffingtonpost.com/entry/melanie-brown-scary-spice_us_5b9d32d9e4b03a1dcc856cdb...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 14 paragraphs (2408 chars)
# Processing URL: https://www.huffingtonpost.com/entry/omarosa-says-leaving-white-house-like-leaving-plantation_us_5a9389a1e4b03b55731d86a7...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 26 paragraphs (5578 chars)
# Processing URL: https://www.huffingtonpost.com/entry/donald-trump-hotel-washington_us_5810ecdfe4b02b1d9e6441d4...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 23 paragraphs (3652 chars)
# Processing URL: https://www.huffingtonpost.com/entry/mit-action-plan-global-warming_us_5627eb62e4b02f6a900f69dd...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 7 paragraphs (4029 chars)
# Processing URL: https://www.huffingtonpost.com/entry/james-corden-has-a-carpool-karaoke-level-strategy-for-trump-interview_us_58d3cd42e4b0b22b0d1a4f26...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 37 paragraphs (6106 chars)
# Processing URL: https://www.huffingtonpost.com/entry/congress-sends-trump-legislation-for-disaster-aid-and-debt-limit-increase_us_59b2addce4b0dfaafcf79700...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 4 paragraphs (1235 chars)
# Processing URL: https://www.huffingtonpost.com/entry/ryan-murphy-pose-fx_us_5a441d68e4b025f99e198fcb...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 10 paragraphs (2099 chars)
# Processing URL: https://www.huffingtonpost.com/entry/mike-huckabee-2016_us_560bf437e4b0768126fff8de... ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 3 paragraphs (347 chars)
#
# Processing URL: https://www.huffingtonpost.com/entry/plumen-002-cfl_us_5b9dc94be4b03a1dcc8cde35...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 20 paragraphs (3447 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 34 paragraphs (5575 chars)
# Processing URL: https://www.huffingtonpost.com/entry/extrovert-environmental-cues-children-introverts_us_5b9db09ee4b03a1dcc8b8860...
# Processing URL: https://www.huffingtonpost.com/entry/kanye-west-mothers-death_us_558cbd8be4b081449b4c91e5...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 28 paragraphs (9406 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 11 paragraphs (2522 chars)
# Processing URL: https://www.huffingtonpost.com/entry/what-if-im-not-as-strong-_b_6944954.html...
# Processing URL: https://www.huffingtonpost.com/entry/huffpost-live-set-designers-roman-and-williams_us_5b9c229ae4b03a1dcc7c8b31...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 10 paragraphs (4432 chars)
# Processing URL: https://www.huffingtonpost.com/entry/i-want-to-start-reading-b_us_5bb3fa65e4b066f8d252ada7...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 4 paragraphs (976 chars)
# Processing URL: https://www.huffingtonpost.com/entry/sleep-apnea-women_us_5b9c5a69e4b03a1dcc7dfce3...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 24 paragraphs (8119 chars)
# Processing URL: https://www.huffingtonpost.com/entry/stroke-brainstem-sleep-apnea_us_5b9ddd81e4b03a1dcc8de9fe...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 17 paragraphs (3767 chars)
# Processing URL: https://www.huffingtonpost.com/entry/nate-ebner-rio-olympics_us_578cd587e4b0c53d5cfa0d2f...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (2503 chars)
# Processing URL: https://www.huffingtonpost.com/entry/houston-synagogue-yom-kippur-hurricane-harvey_us_59cd2059e4b03b0879cfeff1...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 32 paragraphs (6521 chars)
# Processing URL: http://www.fastcompany.com/3014147/creative-conversations/the-truth-about-unplugging-and-vacation...
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
# Processing URL: https://www.huffingtonpost.com/entry/i-lost-weight-chris-ponce_us_5b9d5eb6e4b03a1dcc8726f3...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 28 paragraphs (7410 chars)
# Processing URL: https://www.huffingtonpost.com/entry/the-secret-life-of-pets-clip_us_577d35d7e4b09b4c43c1d7b1...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 3 paragraphs (370 chars)
# Processing URL: https://www.huffingtonpost.com/entry/children-sensory-issues_us_5b9bb25ee4b03a1dcc79aa23...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (1557 chars)
# Processing URL: https://www.huffingtonpost.com/entry/andrew-wiggins-kansas-block-dunk_us_5bb74ef3e4b097869fd4f093...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 28 paragraphs (5989 chars)
# Processing URL: https://www.huffingtonpost.com/entry/poor-people-may-suffer-mo_us_5b9dc5b3e4b03a1dcc8cb159...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 16 paragraphs (2900 chars)
# Processing URL: https://www.huffingtonpost.com/entry/uw-whitewater-racist-photo_us_56c772b6e4b041136f16e544...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 27 paragraphs (5993 chars)
# Processing URL: https://www.huffingtonpost.com/entry/the-endless-fall-of-suge-_n_7780192.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 17 paragraphs (3345 chars)
# Processing URL: https://www.huffingtonpost.com/entry/11-things-women-were-told_n_6395502.html...
# Processing URL: http://www.nytimes.com/2016/03/27/movies/don-cheadle-on-becoming-miles-davis.html?_r=1&referer=https:/www.google.com/...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 18 paragraphs (4096 chars)
# Processing URL: https://www.huffingtonpost.com/entry/valentines-day-chocolates_us_5b9cc2eee4b03a1dcc819d21...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 6 paragraphs (1779 chars)
# Processing URL: https://www.huffingtonpost.com/entry/democratic-party-reverses-course-will-release-platform-document_us_577295fbe4b017b379f761ac...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 6 paragraphs (1894 chars)
# Processing URL: https://www.huffingtonpost.com/entry/what-does-your-starbucks_us_5b9de0ede4b03a1dcc8e1147...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (2197 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 6 paragraphs (1173 chars)
# Processing URL: https://www.huffingtonpost.com/entry/heroin-and-opioid-crisis-gridlocked-by-discusssion_us_596524a0e4b0911162fc2f63...
# Processing URL: https://www.huffingtonpost.com/entry/home-gadgets-that-are-going-extinct_us_5b9cdfcde4b03a1dcc829a4b...
# Processing URL: https://www.huffingtonpost.com/entry/pizza-hut-flatbread_us_5b9d49a0e4b03a1dcc8653ac...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (1352 chars)
# Processing URL: https://www.huffingtonpost.com/entry/youtube-delhi-rape-documentary_n_6807032.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 5 paragraphs (852 chars)
# Processing URL: https://www.huffingtonpost.com/entry/cancer-type-socioeconomic-status_n_5379853.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 14 paragraphs (2922 chars)
# Processing URL: https://www.huffpost.com/entry/mindfulness-meditation-racial-trauma_l_5f19df61c5b6128e6822bc25...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 8 paragraphs (1785 chars)
# Processing URL: https://www.huffingtonpost.com/entry/california-wildfires_us_59dc9f2de4b0208970cf7431...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 24 paragraphs (7783 chars)
# Processing URL: https://www.huffingtonpost.com/entry/confessions-of-a-chubby-girl_b_5667103.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 25 paragraphs (6058 chars)
# Processing URL: https://www.huffingtonpost.com/entry/12-ways-pinterest-says-im-failing-my-children_b_6022146.html...
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
# Processing URL: http://www.nydailynews.com/sports/more-sports/serena-williams-game-faces-puts-fear-opponents-2012-u-s-open-article-1.1147665...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 12 paragraphs (2796 chars)
# Processing URL: https://www.huffingtonpost.com/entry/what-chd-robs-from-families_us_58e83361e4b06f8c18beebfb...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 2 paragraphs (555 chars)
# Processing URL: https://www.huffingtonpost.com/entry/cloud-eye-control-half-li_b_6488282.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 28 paragraphs (7840 chars)
# Processing URL: https://www.huffingtonpost.com/entry/the-year-my-father-stayed-home-with-me_us_5b9d92b3e4b03a1dcc89add6...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 7 paragraphs (1974 chars)
# Processing URL: https://www.huffingtonpost.com/entry/scott-walker-islam_us_55d77f43e4b08cd3359c21c9...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 16 paragraphs (3442 chars)
# Processing URL: https://www.huffingtonpost.com/entry/natassja-kinski_us_5bb3f43ce4b066f8d2523c42...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 14 paragraphs (3019 chars)
# Processing URL: https://www.huffingtonpost.com/entry/eurozone-breakup-poorest-countries_us_5bb2c583e4b0480ca65bca89...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 30 paragraphs (10266 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 3 paragraphs (483 chars)
# Processing URL: https://www.huffingtonpost.com/entry/recluse-spider-bite-ear-hole-young-woman_us_5b9daaafe4b03a1dcc8b1a0d...
# Processing URL: https://www.huffingtonpost.com/entry/i-really-cant-talk-my-way_b_7775700.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 16 paragraphs (5030 chars)
# Processing URL: https://www.huffingtonpost.com/entry/chef-marcus-samuelsson-on-travel_us_5b9bedb7e4b03a1dcc7b3272...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 7 paragraphs (1062 chars)
# Processing URL: http://espn.go.com/mlb/story/_/id/15633876/mlb-competition-committee-agrees-changes-strike-zone-intentional-walks...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 33 paragraphs (6916 chars)
# Processing URL: https://www.huffpost.com/entry/iran-coronavirus-newspaper_n_5f313980c5b6b9cff7f48a8d...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 19 paragraphs (6074 chars)
# Processing URL: https://www.huffingtonpost.com/entry/ugandan-doctor-ebola-germany_n_5926180.html...
#  ->Parsing HTML content...
#  -> Found article with div.article-body
#  ->Extracted 15 paragraphs (8347 chars)
# Processing URL: https://www.huffingtonpost.com/entry/archaeotourists-mob-ancient-ruins_us_5b9b426ee4b03a1dcc760a7f...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 22 paragraphs (4021 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 8 paragraphs (1972 chars)
# Processing URL: https://www.huffingtonpost.com/entry/maria-bamford-erin-foley_us_5bad1c2ae4b04234e856d19f...
# Processing URL: https://www.huffingtonpost.com/entry/bernie-sanders-marijuana_us_56312967e4b0c66bae5ab86f...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 7 paragraphs (1711 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 12 paragraphs (2632 chars)
# Processing URL: https://www.huffingtonpost.com/entry/what-next_b_5891294.html...
# Processing URL: https://www.huffingtonpost.com/entry/huffpost-hill_n_6426026.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 6 paragraphs (1241 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 3 paragraphs (46 chars)
# Processing URL: https://www.huffingtonpost.com/entry/pennsylvania-police-chief-accused-of-huffing-air-can-on-duty_us_565f4502e4b072e9d1c4632e...
# Processing URL: https://www.huffingtonpost.com/entry/news-roundup-for-march-14-2017_us_58c81994e4b022817b291767...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 27 paragraphs (6609 chars)
# Processing URL: https://www.huffingtonpost.com/entry/44th-anniversary-that-guy_b_5460686.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 12 paragraphs (762 chars)
# Processing URL: https://www.huffingtonpost.com/entry/obama-supreme-court-immigration-rehearing_us_5783f799e4b01edea78f15e2...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 5 paragraphs (1593 chars)
# Processing URL: https://www.huffingtonpost.com/entry/nasty-women-pump-on-the-way-to-planned-parenthood-with_us_587a9c0de4b094e1aa9dc6d2...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 16 paragraphs (3099 chars)
# Processing URL: https://www.huffingtonpost.com/entry/face-reading-an-advantage_b_5675413.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 14 paragraphs (3756 chars)
# Processing URL: https://www.huffingtonpost.com/entry/under-trump-muslim-book-publishers-are-fighting-against-hate_us_58d3dc9be4b02d33b7492887...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (2346 chars)
# Processing URL: https://www.huffpost.com/entry/fani-willis-joyce-vance-donald-trump-raffensperger-phone-call-state-of-mind-evidence_n_6294ee92e4b0cda85dc20c3c...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 38 paragraphs (6778 chars)
# Processing URL: https://www.huffingtonpost.com/entry/barbie-for-president_us_5b9b89dae4b03a1dcc78727f...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 28 paragraphs (4168 chars)
# Processing URL: https://www.huffingtonpost.com/entry/charlie-sheen-denise-rich_us_5b9bea1ce4b03a1dcc7b1925...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (3309 chars)
# Processing URL: http://www.thefader.com/2017/10/15/trans-memorial-obituaries...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 21 paragraphs (3680 chars)
# Processing URL: https://www.huffingtonpost.com/entry/surfing-climate-change-donald-trump_us_58c05f3be4b0d1078ca38474...
#  ->Parsing HTML content...
#  -> Found article with div.article-body
#  ->Extracted 19 paragraphs (3962 chars)
# Processing URL: https://www.huffingtonpost.com/entry/american-health-care_us_5b9c60c8e4b03a1dcc7e32da...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 12 paragraphs (2355 chars)
# Processing URL: https://www.huffingtonpost.com/entry/cute-kid-note-thank-you-michelle-obama_us_5b9c93a6e4b03a1dcc7ff812...
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
# Processing URL: https://www.huffingtonpost.com/entry/baby-shares-birthday-with-mom-and-dad_us_5b9b57a7e4b03a1dcc76c60f...
# Processing URL: https://www.huffingtonpost.com/entry/home-for-christmas_b_13680266.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 12 paragraphs (2563 chars)
# Processing URL: http://greatist.com/health/21-germiest-places-youre-not-cleaning...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 17 paragraphs (3551 chars)
# Processing URL: https://www.huffingtonpost.com/entry/megyn-kelly-morning-show_us_59c52999e4b01cc57ff1b6f2...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 54 paragraphs (7687 chars)
# Processing URL: https://www.huffingtonpost.com/entry/has-the-eu-really-solved-its-refugee-crisis_us_595f9e77e4b085e766b511f4...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 26 paragraphs (11824 chars)
# Processing URL: https://www.huffingtonpost.com/entry/the-viral-storm_us_5b9c5b4fe4b03a1dcc7e078f...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 25 paragraphs (5606 chars)
# Processing URL: https://www.huffingtonpost.com/entry/best-employers-fortune-500_us_5b9bb13ae4b03a1dcc79a16f...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 27 paragraphs (6664 chars)
# Processing URL: https://www.huffingtonpost.com/entry/go-ahead-act-like-a-guy-b_b_5922902.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 15 paragraphs (3943 chars)
# Processing URL: https://www.huffingtonpost.com/entry/corrupt-countries_n_6261700.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (4737 chars)
# Processing URL: https://www.huffingtonpost.com/entry/5-lessons-i-learned-from-my-kids-about-grieving_us_58c2fdb3e4b054a0ea6a8e48...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 21 paragraphs (4358 chars)
# Processing URL: https://www.huffingtonpost.com/entry/mary-ellen-vernon-loves-b_us_5b9c9550e4b03a1dcc8008dd...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 35 paragraphs (19831 chars)
# Processing URL: https://www.huffpost.com/entry/china-muslim-camps-united-nations_n_5b7445c6e4b02b415d748a00...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (2040 chars)
# Processing URL: https://www.huffingtonpost.com/entry/march-for-science_us_58fa529be4b0f02c3870e9a6...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 41 paragraphs (10789 chars)
# Processing URL: https://www.huffingtonpost.com/entry/wyoming-next-generation-science_us_5bb151aae4b09bbe9a5e7cd8...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 8 paragraphs (1884 chars)
# Processing URL: https://www.huffingtonpost.com/entry/president-obama-we-need-t_us_5bb2fc65e4b0480ca66070cf...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 16 paragraphs (3665 chars)
# Processing URL: https://www.huffingtonpost.com/entry/craziest-places-for-cat-l_us_5b9cee31e4b03a1dcc830775...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 34 paragraphs (7040 chars)
# Processing URL: https://www.huffingtonpost.com/entry/most-expensive-wedding-cake_us_5b9cd497e4b03a1dcc8239d3...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 39 paragraphs (8321 chars)
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 7 paragraphs (1161 chars)
# Processing URL: https://www.huffingtonpost.com/entry/tubed-tomato-paste_us_5b9b3da6e4b03a1dcc75dbe2...
# Processing URL: https://www.huffingtonpost.com/entry/yankee-doodle-polling-pub_b_7672062.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 29 paragraphs (8206 chars)
# Processing URL: https://www.huffingtonpost.com/entry/cancer-awareness_us_5b9c690be4b03a1dcc7e6e85...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 7 paragraphs (1023 chars)
# Processing URL: https://www.huffingtonpost.com/entry/health-makeover_n_5691231.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 5 paragraphs (1568 chars)
# Processing URL: https://www.huffingtonpost.com/entry/backseat-taxi-photos_us_5a036fc2e4b0937b510f5abd...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 22 paragraphs (6136 chars)
# Processing URL: https://www.huffingtonpost.com/entry/strawberry-season_us_5b9d4cd6e4b03a1dcc866bca...
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
# Processing URL: https://www.huffingtonpost.com/entry/donald-trump-disabilities-retards_us_5801707ae4b0e8c198a85154...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 17 paragraphs (3562 chars)
# Processing URL: https://www.huffingtonpost.com/entry/trump-southern-storms-aid_us_5885bdbbe4b096b4a232ce85...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 32 paragraphs (5877 chars)
# Processing URL: https://www.huffingtonpost.com/entry/christie-brinkley-divorce_us_5b9b6bb3e4b03a1dcc776644...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 19 paragraphs (4343 chars)
# Processing URL: https://www.huffingtonpost.com/entry/dont-fuck-the-patriarchy_b_13436852.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 20 paragraphs (3329 chars)
# Processing URL: https://www.huffingtonpost.com/entry/what-does-your-husband-do-the-secret-identity-of_us_58fdb11fe4b0f02c3870ec31...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 25 paragraphs (5600 chars)
# Processing URL: https://www.huffingtonpost.com/entry/weekly-roundup-of-ebay-vi_us_5b9de182e4b03a1dcc8e1586...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 11 paragraphs (2605 chars)
# Processing URL: https://www.huffingtonpost.com/entry/military-leaders-climate-change-advice-donald-trump_us_582a4082e4b060adb5700332...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 39 paragraphs (11415 chars)
# Processing URL: https://www.huffingtonpost.com/entry/african-first-ladies-summit-2013-photos_us_5b9d50e7e4b03a1dcc8695f1...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 8 paragraphs (1865 chars)
# Processing URL: https://www.huffingtonpost.com/entry/jennifer-aniston-living-proof-campaign-hair_us_5b9c650ee4b03a1dcc7e546e...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 12 paragraphs (1187 chars)
# ...
# Processing URL: https://www.huffingtonpost.com/entry/post_us_5b9c155fe4b03a1dcc7c3489...
# Processing URL: https://www.huffingtonpost.com/entry/michelle-obama-state-of-the-union-dress-2014_us_5b9dd1f7e4b03a1dcc8d4cf0...
# Processing URL: https://www.huffingtonpost.com/entry/super-bowl-recipes-snacks_us_5b9cc48de4b03a1dcc81ad0a...
# Processing URL: http://www.motherjones.com/politics/2016/05/trump-white-nationalist-california-delegate-response-email-pledge-database-error...
# Processing URL: https://www.huffingtonpost.com/entry/zendaya-colorism-hollywood_us_5ade10eae4b0df502a4e529f...
# Processing URL: https://www.huffingtonpost.com/entry/how-to-make-daily-progres_b_5924014.html...
# Processing URL: https://www.huffingtonpost.com/entry/how-nonresistance-and-good-company_b_5298832.html...
# Processing URL: https://www.huffingtonpost.com/entry/brian-williams-letterman_n_6641064.html...
# Processing URL: https://www.huffpost.com/entry/amber-heard-sister-reacts-to-johnny-depps-vmas-cameo_n_630cf4fae4b088f742365be6...
# Processing URL: http://www.nytimes.com/2016/03/02/sports/ncaafootball/ivy-league-moves-to-eliminate-tackling-at-practices.html?smid=tw-nytimes&smtyp=cur...
# Processing URL: https://www.huffingtonpost.com/entry/young-black-powerful_b_6225208.html...
# Processing URL: https://www.huffingtonpost.com/entry/james-cameron-fashion_us_5b9b880ae4b03a1dcc785d6c...
# Processing URL: https://www.huffingtonpost.com/entry/when-cancer-takes-your-hair_us_5b9cdfbce4b03a1dcc829a14...
# Processing URL: https://www.huffingtonpost.com/entry/supermarket-without-bees_us_5bb13c02e4b09bbe9a5cea3b...
# Processing URL: https://www.huffingtonpost.com/entry/3-chicago-cops-charged-in-cover-up-of-laquan-mcdonald-shooting_us_5952ad8ee4b02734df2e0972...
# Processing URL: https://www.huffingtonpost.com/entry/these-secret-gardens-are-perfect-little-surprises-in-cities-around-the-world_us_55708ae9e4b0a9eb44eb99b5...
# Processing URL: https://www.huffingtonpost.com/entry/doj-war-on-leaks-shows-russia-stories-are-not-fake_us_5984c1d8e4b00833d1de27c1...
# Processing URL: https://www.huffingtonpost.com/entry/melissa-mccarthy-wants-to-make-shopping-better-for-everyone_us_55d31ccde4b07addcb43ea9b...
# Processing URL: https://www.huffingtonpost.com/entry/getting-married-in-mexico_us_5b9b4d64e4b03a1dcc7675e9...
# Processing URL: https://www.huffingtonpost.com/entry/eva-mendes-ny-co_us_5b9d82ffe4b03a1dcc88f300...
# Processing URL: https://www.huffingtonpost.com/entry/farmers-markets-with-chin_b_7250416.html...
# Processing URL: https://www.huffingtonpost.com/entry/man-calls-911-to-get-air-conditioner-fixed-police_us_55b101b4e4b08f57d5d3caf5...
# Processing URL: https://www.huffingtonpost.com/entry/patricia-arquette-acceptance-speech_b_6737852.html...
# Processing URL: https://www.huffingtonpost.com/entry/celebrating-pride_us_5bafb690e4b0ad76926098ac...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 20 paragraphs (2905 chars)
# Processing URL: https://www.huffingtonpost.com/entry/we-must-reduce-mass-incarceration-in-the-us-not_us_591f4ed4e4b07617ae4cbbdd...
#  ->Parsing HTML content...
#  -> Found article with article.entry-content
#  ->Extracted 10 paragraphs (1720 chars)
# Processing URL: https://www.huffpost.com/entry/jane-fonda-trump-hitler_n_5bddd5c5e4b01ffb1d02b2c5...
# Processing URL: https://www.huffingtonpost.com/entry/the-moment-i-knew_us_5b9d35b6e4b03a1dcc8591eb...
# Processing URL: https://www.huffingtonpost.com/entry/the-24hour-boob-job_b_7282486.html...
# Processing URL: https://www.huffingtonpost.com/entry/travels-with-journey-the_us_5b9d6219e4b03a1dcc875262...
# Processing URL: https://www.huffingtonpost.com/entry/provences-pont-du-gard-an_b_7564290.html...
# Processing URL: http://www.thedailybeast.com/newsweek/2012/12/23/david-ansen-recalls-when-aids-silenced-the-arts.html...
# Processing URL: https://www.huffingtonpost.com/entry/fall-cocktails-the-six-be_us_5b9d8978e4b03a1dcc8941e0...
# Processing URL: https://www.huffingtonpost.com/entry/device-keeps-liver-alive-outside-body_us_5b9cef7ae4b03a1dcc83140c...
# Processing URL: https://www.huffingtonpost.com/entry/fox-sports-jamie-horowitz-fired-sexual-harassment_us_595aa27ae4b05c37bb7fcf8e...
# Processing URL: https://www.huffingtonpost.com/entry/america-is-in-a-state-of_b_10778936.html...
# Processing URL: https://www.huffingtonpost.com/entry/meat-recipes-steak-pork_us_5b9dd674e4b03a1dcc8d9657...
# Processing URL: https://www.huffingtonpost.com/entry/4-reasons-to-rethink-entrepreneurship-education-_b_6680338.html...
# Processing URL: https://www.huffingtonpost.com/entry/integrative-medicine_us_5b9d6bace4b03a1dcc87ce02...
# Processing URL: https://www.huffingtonpost.com/entry/caption-a-photo_us_5b9c97a5e4b03a1dcc801d4d...
# Processing URL: https://www.huffingtonpost.com/entry/annoying-travelers_us_5b9db8d5e4b03a1dcc8c0512...
# Processing URL: https://www.huffingtonpost.com/entry/diet-nutrition_us_5b9c1347e4b03a1dcc7c297e...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 13 paragraphs (2494 chars)
# Processing URL: https://www.huffingtonpost.com/entry/donald-trump-hispanic-chamber-of-commerce_us_55e5ed4ee4b0c818f61952f9...
# Processing URL: https://www.huffingtonpost.com/entry/the-worst-place-on-a-cruise-ship_us_5b9cfa70e4b03a1dcc837686...
# Processing URL: https://www.huffingtonpost.com/entry/started-from-the-bottom-drake_us_5bb41554e4b066f8d2547912...
# Processing URL: https://www.huffingtonpost.com/entry/paul-davis-strip-club_n_5855020.html...
# Processing URL: https://www.huffingtonpost.com/entry/travita-travel-charity-app_us_55d25860e4b0ab468d9e22f1...
# Processing URL: https://www.huffingtonpost.com/entry/jeb-bush-death-penalty_us_563626c4e4b063179912b13b...
# Processing URL: https://www.huffingtonpost.com/entry/barnard-college-title-ix-investigations_n_6432596.html...
# Processing URL: https://www.huffingtonpost.com/entry/can-religious-freedom-be-used-to-discriminate_b_6997088.html...
# Processing URL: https://www.huffingtonpost.com/entry/out-of-the-closet-reflections-one-year-later_us_5bafb13de4b0ad7692602ede...
# Processing URL: https://www.huffingtonpost.com/entry/infinity-war-timeline-answers_us_5b06b703e4b05f0fc8456887...
# Processing URL: https://www.huffingtonpost.com/entry/inspirational-quotes_us_5b9cf9f6e4b03a1dcc83716f...
# Processing URL: https://www.huffingtonpost.com/entry/thanksgiving-calories-burned-exercise_us_5b9c832ce4b03a1dcc7f555c...
# Processing URL: https://www.huffingtonpost.com/entry/technology-to-cultivate-e_b_5928386.html...
# Processing URL: https://www.huffingtonpost.com/entry/creativity_us_5b9cde0ee4b03a1dcc8290ee...
# Processing URL: https://www.huffingtonpost.com/entry/is-eating-healthy-food-en_b_5407686.html...
# Processing URL: https://www.huffingtonpost.com/entry/how-to-order-a-martini_us_5b9b6470e4b03a1dcc772e53...
# Processing URL: https://www.huffpost.com/entry/charley-barkley-reality-check-covid-anti-vaxxers_n_61330e79e4b0df9fe276aeae...
# Processing URL: https://www.huffingtonpost.com/entry/james-comey-donald-trump-dinner_us_593970f9e4b0c5a35c9d1157...
# Processing URL: https://www.huffingtonpost.com/entry/evolution-right-now-is-in_b_5804274.html...
# Processing URL: https://www.huffingtonpost.com/entry/theater-shooters-wife-removed-all-guns-from-home-because-of-his-mental-state_us_55b25813e4b0a13f9d183ee8...
# Processing URL: https://www.huffingtonpost.com/entry/san-francisco-film-society-embraces-innovation-awareness_b_7295240.html...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 16 paragraphs (2912 chars)
# Processing URL: https://www.huffingtonpost.com/entry/climate-change_us_5bb12b2be4b09bbe9a5bdd70...
# Processing URL: https://www.huffingtonpost.com/entry/ed-gillespies-cynical-attack-on-rights-restoration-would-drag-virginia-backward_us_59efd190e4b04917c5941292...
# Processing URL: https://www.huffingtonpost.com/entry/brca-1_b_5540069.html...
# Processing URL: https://www.huffingtonpost.com/entry/uncircling-the-wagons-phi_us_5b9d7959e4b03a1dcc887793...
# Processing URL: https://www.huffingtonpost.com/entry/cdc-reports-first-us-zika-death-in-puerto-rico_us_5723c074e4b01a5ebde5ac5a...
# Processing URL: https://www.huffingtonpost.com/entry/9-year-old-challenges-boys-only-robotics-program_us_559d50ade4b01c2162a5a9e3...
# Processing URL: https://www.huffingtonpost.com/entry/arizona-prison-bus-crash_us_55ca41b8e4b0f73b20bad2c6...
# Processing URL: https://www.huffingtonpost.com/entry/low-teacher-salary-report_n_5615480.html...
# Processing URL: https://www.huffingtonpost.com/entry/sick-day-excuses-worst_us_5bb300aae4b0480ca66107d7...
# Processing URL: https://www.huffingtonpost.com/entry/the-trump-effect-positive-attitudes-toward-arabs_us_5a345a22e4b0e1b4472ae667...
# Processing URL: https://www.huffingtonpost.com/entry/tony-awards-nominee_n_5233294.html...
# Processing URL: https://www.huffingtonpost.com/entry/christians-easy-prey-for-propaganda_us_598dc3cae4b0ed1f464c0a2d...
# Processing URL: https://www.huffingtonpost.com/entry/no-one-hates-their-job-anymore_us_571907c2e4b0c9244a7b3387...
# Processing URL: https://www.huffingtonpost.com/entry/5-easy-asian-chicken-recipes_b_6284230.html...
# Processing URL: https://www.huffingtonpost.com/entry/timothy-geithner-debt-ceiling_us_5bb2dd07e4b0480ca65d8b7d...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (1700 chars)
# Processing URL: https://www.huffingtonpost.com/entry/uninsured-rate-states-obamacare_us_55c7e3f9e4b0f1cbf1e561f7...
# Processing URL: https://www.huffingtonpost.com/entry/dental-health_us_5b9c0775e4b03a1dcc7bdef7...
# Processing URL: https://www.huffingtonpost.com/entry/productivity-tips_b_5351819.html...
# Processing URL: https://www.huffingtonpost.com/entry/soldier-gets-heartwarming-welcome-home-from-sorority-sisters_us_5603fc4de4b00310edfa24b4...
# Processing URL: https://www.huffingtonpost.com/entry/thirty-is-bigger-than-i-t_b_7235722.html...
# Processing URL: https://www.huffingtonpost.com/entry/americas-afghan-highway-to-nowhere_us_59551961e4b0da2c7321bcaa...
# Processing URL: https://www.huffingtonpost.com/entry/cheap-celeb-finds_n_5549973.html...
# Processing URL: https://www.huffingtonpost.com/entry/10-statements-that-shouldve-disqualified-roy-moore_us_5a2ae15fe4b04e0bc8f3b44f...
# Processing URL: https://www.huffingtonpost.com/entry/what-to-say-to-all-moms_b_5027487.html...
# Processing URL: https://www.huffingtonpost.com/entry/carrie-underwood-skydiving_us_584d95a1e4b04c8e2bb0497c...
# Processing URL: https://www.huffingtonpost.com/entry/the-voices-audra-mclaughl_b_5188552.html...
# Processing URL: https://www.huffingtonpost.com/entry/ryan-seacrest-squad-goals-tv-show_us_5620e966e4b06462a13b94fb...
# Processing URL: https://www.huffingtonpost.com/entry/housing-crisis-in-california-forces-more-students-into_us_59d3d87be4b0da85e7f5ec42...
# Processing URL: https://www.huffingtonpost.com/entry/what-happens-when-kids-go-cold-turkey-from-their-screens-for-5-days_b_5700805.html...
# Processing URL: http://money.cnn.com/2015/09/24/media/donald-trump-roger-ailes-meeting/index.html...
# Processing URL: http://pubx.co/drC2mA...
# Processing URL: https://www.huffingtonpost.com/entry/why-jeffrey-sterling-dese_b_6414952.html...
# Processing URL: https://www.huffingtonpost.com/entry/samantha-bee-trump-roast_us_59054eb8e4b02655f83e0206...
# Processing URL: https://www.huffingtonpost.com/entry/trump-clinton-arizona_us_573cd680e4b0ef86171d28d1...
# Processing URL: https://www.huffingtonpost.com/entry/everything-i-learned-i-le_us_5b9dd65fe4b03a1dcc8d9411...
# Processing URL: https://www.huffingtonpost.com/entry/katy-perry-cultural-appropriation_n_5634303.html...
# Processing URL: https://www.huffingtonpost.com/entry/more-americans-trust-cnn-than-trump-poll_us_595bc9e9e4b0da2c73258bf2...
# Processing URL: https://www.huffingtonpost.com/entry/why-donald-trump_us_5970e157e4b0d72667b05ee9...
# Processing URL: https://www.huffingtonpost.com/entry/chris-cuomo-kellyanne-conway_us_5a56e77fe4b0a300f905c796...
# Processing URL: https://www.huffingtonpost.com/entry/trump-national-security_us_57a8d2dce4b0aae2a5a0ba36...
# Processing URL: https://www.huffingtonpost.com/entry/easy-retirement-tips_b_6248962.html...
# Processing URL: https://www.huffingtonpost.com/entry/game-of-thrones-officially-return-2019_us_5a4e81a2e4b01e1a4b13bdf1...
# Processing URL: https://www.huffingtonpost.com/entry/pope-francis-fear-politics_us_5aa5873fe4b086698a9ef192...
# Processing URL: https://www.huffingtonpost.com/entry/a-decorated-cookie-you-wo_us_5b9d3857e4b03a1dcc85a85f...
# Processing URL: https://www.huffingtonpost.com/entry/greatest-gif-olympics-diving_us_57aec4d2e4b0718404119604...
# Processing URL: https://www.huffingtonpost.com/entry/5-ways-to-get-a-proposal_us_5b9c2b39e4b03a1dcc7ccc31...
# Processing URL: https://www.huffpost.com/entry/vanessa-bryant-message-champion-lakers_n_5f842ef4c5b62f97bac55233...
# Processing URL: https://www.huffingtonpost.com/entry/i-lost-weight-leah-smith_us_5b9cf323e4b03a1dcc8337f3...
# Processing URL: https://www.huffingtonpost.com/entry/rob-gronkowski-dirty-hit-tredavious-white_us_5a254f6be4b03c44072ed0cf...
# Processing URL: http://curbed.com/archives/2013/06/28/peek-inside-five-of-americas-most-techedout-hotels.php...
# Processing URL: https://www.huffingtonpost.com/entry/new-years-resolution-3-ea_us_5b9dc053e4b03a1dcc8c6d52...
# Processing URL: https://www.huffingtonpost.com/entry/roy-moore-alabama-republicans_us_59e8ce2be4b061a7badae062...
# Processing URL: http://www.buzzfeed.com/rosiegray/breitbart-editor-ordered-staffers-to-stop-defending-michelle...
# Processing URL: https://www.huffingtonpost.com/entry/international-day-of-the-girl-child-helping-girls_us_59dd0e79e4b0b992a821476b...
# Processing URL: https://www.huffingtonpost.com/entry/monique-lhuillier-bridal-nicki-minaj_us_5b9c92cee4b03a1dcc7ff325...
# Processing URL: http://www.washingtonblade.com/2017/03/08/devos-meets-with-lgbt-groups-over-withdrawal-of-trans-student-protections/...
# Processing URL: https://www.huffingtonpost.com/entry/bacon-brie-potato-tart-a_us_5b9df2b1e4b03a1dcc8f50ab...
# Processing URL: https://www.huffingtonpost.com/entry/he-won-now-what-the-opportunity-for-tech-execs_us_5828c237e4b057e23e314620...
# Processing URL: https://www.huffingtonpost.com/entry/how-blacklivesmatter-inspires-people-to-put-faith-into-action_us_55c53880e4b0f1cbf1e52a18...Processing URL: http://www.lilsugar.com/Breastfeeding-Apps-21240567...
# Processing URL: https://www.huffingtonpost.com/entry/off-the-beaten-menu-8-reg_b_5654605.html...
# Processing URL: https://www.huffingtonpost.com/entry/avatars-schizophrenia-computer-voices-in-heads_us_5b9d347ce4b03a1dcc85806c...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 9 paragraphs (1254 chars)
#
# Processing URL: https://www.huffingtonpost.com/entry/france-vs-the-us-croissan_us_5b9d8963e4b03a1dcc894049...
# Processing URL: https://www.huffingtonpost.com/entry/charles-hooks-barber-shop-murder_n_6630138.html...
# Processing URL: https://www.huffingtonpost.com/entry/dennis-adams-wife-nude-photos_us_5683fc63e4b0b958f65ae583...
# Processing URL: https://www.huffingtonpost.com/entry/cooking-off-the-cuff-a-free-form-apple-pie_us_5b9db04ae4b03a1dcc8b839f...
# Processing URL: https://www.huffpost.com/entry/jello-skin-tiktok_l_62b5bc22e4b04a6173695b03...
#  ->Parsing HTML content...
#  -> Found article with article.entry__content
#  ->Extracted 20 paragraphs (4086 chars)
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
#  ->Parsing HTML content...
#  -> No article content found with standard selectors
#  -> Skipping (connection failed): https://broadly.vice.com/en_us/article/that-time-as-a-gay-gu...
#  -> Skipping (too many redirects): http://recode.net/2015/08/07/verizons-new-plans-are-simpler-...
# ✅ Batch 9/9 complete - 43/936 successful

# %% [markdown]
# Investigating some of the links that no content was found, it indeed had no content. But for others that was not the case.
# Will proceed for now and revist the scraping function after buidling the multi agent model.

# %%
news_df = pd.read_csv('progress_checkpoint.csv')
print(f"The dataset has {news_df.shape[1]} features and {news_df.shape[0]} rows.\nThe names of the categories are: {news_df.columns.tolist()}")
news_df.head()
# Out:
# The dataset has 9 features and 20953 rows.
# The names of the categories are: ['link', 'headline', 'category', 'short_description', 'authors', 'date', 'article_url', 'article', 'scrapable']
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/what-if-w...
# 1  https://www.huffingtonpost.comhttp://www.washi...
# 2  https://www.huffingtonpost.com/entry/time-runs...
# 3  https://www.huffingtonpost.com/entry/one-glimp...
# 4  https://www.huffingtonpost.com/entry/mens-swea...
#
#                                             headline  category  \
# 0    What If We Were All Family Generation Changers?    IMPACT
# 1        Firestorm At AOL Over Employee Benefit Cuts  BUSINESS
# 2  Dakota Access Protesters Arrested As Deadline ...  POLITICS
# 3  One Glimpse Of These Baby Kit Foxes And You'll...     GREEN
# 4  Mens' Sweat Pheromone, Androstadienone, Influe...   SCIENCE
#
#                                    short_description  \
# 0  What if, in doing so, we won't just create new...
# 1  It should have been a glorious week for AOL ch...
# 2  A few protesters who refused to leave remained...
# 3                                                NaN
# 4  Scientists didn't know if humans played that g...
#
#                                              authors        date  \
# 0  Matt Murrie, ContributorEdupreneur, Cofounder/...  2014-06-20
# 1                                                NaN  2014-02-08
# 2  Michael McLaughlin & Josh Morgan, The Huffingt...  2017-02-22
# 3                                                NaN  2014-05-14
# 4                                     Melissa Cronin  2013-06-02
#
#                                          article_url  \
# 0  https://www.huffingtonpost.com/entry/what-if-w...
# 1  http://www.washingtonpost.com/business/economy...
# 2  https://www.huffingtonpost.com/entry/time-runs...
# 3  https://www.huffingtonpost.com/entry/one-glimp...
# 4  https://www.huffingtonpost.com/entry/mens-swea...
#
#                                              article  scrapable
# 0  In Tara Stone's conversation from the What If....       True
# 1                                                NaN       True
# 2  CANNON BALL, N.D. ― A few dozen Dakota Access ...       True
# 3  Photographer Donald Quintana melts our hearts ...       True
# 4                                                NaN       True

# %%
#re-check feature that has missing value
df[df["category"]=="GREEN"][:5]
# Out:
#                                                      link  \
# 131494  https://www.huffingtonpost.com/entry/one-glimp...
# 23177   https://www.huffingtonpost.com/entry/californi...
# 39940   https://www.huffingtonpost.com/entry/surfing-c...
# 51124   https://www.huffingtonpost.com/entry/military-...
# 102120  https://www.huffingtonpost.com/entry/why-we-ne...
#
#                                                  headline category  \
# 131494  One Glimpse Of These Baby Kit Foxes And You'll...    GREEN
# 23177   Firefighters Battle To Control 15 Wildfires Ra...    GREEN
# 39940   Trump Won't Save Us From Climate Change. Maybe...    GREEN
# 51124   Global Security Leaders Have Some Climate Chan...    GREEN
# 102120  Why We Need to Change How We Talk About Climat...    GREEN
#
#                                         short_description  \
# 131494
# 23177   The blazes have killed at least 13 people and ...
# 39940   “Surfers will be the canaries in the coal mine...
# 51124                Too bad he thinks it's a giant hoax!
# 102120  Presenting climate change and its causes as th...
#
#                                                   authors        date  \
# 131494                                                     2014-05-14
# 23177                        By Marc Vartabedian, Reuters  2017-10-10
# 39940                                      Lydia O'Connor  2017-03-22
# 51124                                      Chris D'Angelo  2016-11-15
# 102120  Maguire Mealy, ContributorGraduate, McGill Uni...  2015-04-16
#
#                                               article_url  \
# 131494  https://www.huffingtonpost.com/entry/one-glimp...
# 23177   https://www.huffingtonpost.com/entry/californi...
# 39940   https://www.huffingtonpost.com/entry/surfing-c...
# 51124   https://www.huffingtonpost.com/entry/military-...
# 102120  https://www.huffingtonpost.com/entry/why-we-ne...
#
#                                                   article  scrapable
# 131494  Photographer Donald Quintana melts our hearts ...       True
# 23177   SANTA ROSA, Calif., Oct 10 (Reuters) - Firefig...       True
# 39940   For surfers, countering PresidentDonald Trump’...       True
# 51124   International military and security experts ha...       True
# 102120  The scientific community has reached a resound...       True

# %%
news_df.isna().sum()
# Out:
# link                     0
# headline                 2
# category                 0
# short_description     1972
# authors               3767
# date                     0
# article_url              0
# article              16144
# scrapable                0
# dtype: int64

# %%
#check for missing values
df.isna().sum()
# Out:
# link                     0
# headline                 0
# category                 0
# short_description        0
# authors                  0
# date                     0
# article_url              0
# article              16139
# scrapable                0
# dtype: int64

# %%
#fill missing values with nothing
news_df.fillna('',inplace=True)

#check for missing values
news_df.isna().sum()
# Out:
# link                 0
# headline             0
# category             0
# short_description    0
# authors              0
# date                 0
# article_url          0
# article              0
# scrapable            0
# dtype: int64

# %%
def create_unified_doc(row):

    parts = []
    # Add components only if they exist and aren't empty
    if pd.notna(row.get('headline')) and str(row['headline']).strip():
        parts.append(f"Headline: {row['headline']}")

    if pd.notna(row.get('date')) and str(row['date']).strip():
        parts.append(f"Date: {row['date']}")
    
    if pd.notna(row.get('authors')) and str(row['authors']).strip():
        parts.append(f"Author: {row['authors']}")
    
    if pd.notna(row.get('short_description')) and str(row['short_description']).strip():
        parts.append(f"Summary: {row['short_description']}")
    
    if pd.notna(row.get('article')) and str(row['article']).strip():
        parts.append(f"Article: {row['article']}")
    
    return '\n'.join(parts) if parts else 'No available content'


news_df['document'] = news_df.apply(create_unified_doc, axis=1)

# %%
print(news_df['document'].iloc[0])
# Out:
# Headline: What If We Were All Family Generation Changers?
# Date: 2014-06-20
# Author: Matt Murrie, ContributorEdupreneur, Cofounder/Chief Curiosity Curator of What If...?
# Summary: What if, in doing so, we won't just create new opportunities for ourselves, we'll also uncover ways to create new opportunities for our families that may not have otherwise existed?
# Article: In Tara Stone's conversation from the What If...? Conference this past March she begins with the recognition that there is no such thing as a perfect family. It's up to us to be the difference that can make our families better. Tara urges us to go beyond the standards our families have provided and challenges us to push down new paths. What if, in doing so, we won't just create new opportunities for ourselves, we'll also uncover ways to create new opportunities for our families that may not have otherwise existed? The life you have doesn't mean it's the life you've been given. Sometimes we can make the biggest impact on the world by starting with our family. Tara's talk defines generation changers and provides a path of five steps you can take to set the stage for those who come after you. What if you can become a family generation changer? What changes are you going to make to set a new course for the future of your family? A proactive, self-help junkie and advisor in the Student Success Center at Missouri S&T where she graduated with her BS and MS in Technical Communication, Tara is the creator of Remarkable180 that encourages people to stop existing and start living by making changes in their life. Big money interests are running the government — and influencing the news you read. While other outlets are retreating behind paywalls and bending the knee to political pressure, HuffPost is proud to be unbought and unfiltered.Will you help us keep it that way?You can even access our stories ad-free. You've supported HuffPost before, and we'll be honest — we could use your help again. We won't back down from our mission of providing free, fair news during this critical moment. But we can't do it without you. For the first time,we're offering an ad-free experienceto qualifying contributors who support our fearless journalism. We hope you'll join us. You've supported HuffPost before, and we'll be honest — we could use your help again. We won't back down from our mission of providing free, fair news during this critical moment. But we can't do it without you. For the first time,we're offering an ad-free experienceto qualifying contributors who support our fearless journalism. We hope you'll join us. Already contributed?Log in to hide these messages. What If We Were All Family Generation Changers? By entering your email and clicking Sign Up, you're agreeing to let us send you customized marketing messages about us and our advertising partners. You are also agreeing to ourTerms of ServiceandPrivacy Policy.

# %%
#save preprocessed dataset
news_df.to_csv('news_category_dataset.csv', index=False)
